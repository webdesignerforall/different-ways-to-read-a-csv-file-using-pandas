# %%
import pandas as pd

# %%
mydata=pd.read_csv("data/iris.csv")

# %%
mydata
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2         se
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
mydata.shape
# Out:
# (150, 5)

# %%
mydata.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
mydata.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
mydata=pd.read_csv('data/iris.csv',header=1)

# %%
mydata
# Out:
#      5.1  3.5  1.4  0.2         se
# 0    4.9  3.0  1.4  0.2     setosa
# 1    4.7  3.2  1.3  0.2     setosa
# 2    4.6  3.1  1.5  0.2     setosa
# 3    5.0  3.6  1.4  0.2     setosa
# 4    5.4  3.9  1.7  0.4     setosa
# ..   ...  ...  ...  ...        ...
# 144  6.7  3.0  5.2  2.3  virginica
# 145  6.3  2.5  5.0  1.9  virginica
# 146  6.5  3.0  5.2  2.0  virginica
# 147  6.2  3.4  5.4  2.3  virginica
# 148  5.9  3.0  5.1  1.8  virginica
#
# [149 rows x 5 columns]

# %%
mydata=pd.read_csv("data/iris.csv",skiprows=1,names=['sep_len','sep_width','pet_len','pet_width','sps'])

# %%
mydata
# Out:
#      sep_len  sep_width  pet_len  pet_width        sps
# 0        5.1        3.5      1.4        0.2         se
# 1        4.9        3.0      1.4        0.2     setosa
# 2        4.7        3.2      1.3        0.2     setosa
# 3        4.6        3.1      1.5        0.2     setosa
# 4        5.0        3.6      1.4        0.2     setosa
# ..       ...        ...      ...        ...        ...
# 145      6.7        3.0      5.2        2.3  virginica
# 146      6.3        2.5      5.0        1.9  virginica
# 147      6.5        3.0      5.2        2.0  virginica
# 148      6.2        3.4      5.4        2.3  virginica
# 149      5.9        3.0      5.1        1.8  virginica
#
# [150 rows x 5 columns]

# %%
mydata=pd.read_csv("data/iris.csv",skiprows=[2,3])

# %%
mydata
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2         se
# 1             4.6          3.1           1.5          0.2     setosa
# 2             5.0          3.6           1.4          0.2     setosa
# 3             5.4          3.9           1.7          0.4     setosa
# 4             4.6          3.4           1.4          0.3     setosa
# ..            ...          ...           ...          ...        ...
# 143           6.7          3.0           5.2          2.3  virginica
# 144           6.3          2.5           5.0          1.9  virginica
# 145           6.5          3.0           5.2          2.0  virginica
# 146           6.2          3.4           5.4          2.3  virginica
# 147           5.9          3.0           5.1          1.8  virginica
#
# [148 rows x 5 columns]

# %%
mydata=pd.read_csv('data/iris.csv',header=None)

# %%
mydata
# Out:
#                 0            1             2            3          4
# 0    sepal_length  sepal_width  petal_length  petal_width    species
# 1             5.1          3.5           1.4          0.2         se
# 2             4.9            3           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7            3           5.2          2.3  virginica
# 147           6.3          2.5             5          1.9  virginica
# 148           6.5            3           5.2            2  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9            3           5.1          1.8  virginica
#
# [151 rows x 5 columns]

# %%
mydata=pd.read_csv('data/iris.csv',header=None,prefix="var")

# %%
mydata
# Out:
#              var0         var1          var2         var3       var4
# 0    sepal_length  sepal_width  petal_length  petal_width    species
# 1             5.1          3.5           1.4          0.2         se
# 2             4.9            3           1.4          0.2     setosa
# 3             4.7          3.2           1.3          0.2     setosa
# 4             4.6          3.1           1.5          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 146           6.7            3           5.2          2.3  virginica
# 147           6.3          2.5             5          1.9  virginica
# 148           6.5            3           5.2            2  virginica
# 149           6.2          3.4           5.4          2.3  virginica
# 150           5.9            3           5.1          1.8  virginica
#
# [151 rows x 5 columns]

# %%
mydata=pd.read_csv("data/iris.csv",na_values=['.'])

# %%
mydata
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2         se
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
mydata = pd.read_csv("http://winterolympicsmedals.com/medals.csv")

# %%
mydata
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
mydata=pd.read_csv("http://winterolympicsmedals.com/medals.csv",skipfooter=5)

# %%
mydata
# Out:
#       Year      City       Sport      Discipline  NOC                  Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT             individual
# 1     1924  Chamonix     Skating  Figure skating  AUT             individual
# 2     1924  Chamonix     Skating  Figure skating  AUT                  pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL               four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN             ice hockey
# ...    ...       ...         ...             ...  ...                    ...
# 2301  2006     Turin      Skiing   Alpine Skiing  USA        Alpine combined
# 2302  2006     Turin      Skiing   Alpine Skiing  USA           giant slalom
# 2303  2006     Turin      Skiing  Freestyle Ski.  USA                 moguls
# 2304  2006     Turin      Skiing       Snowboard  USA  Giant parallel slalom
# 2305  2006     Turin      Skiing       Snowboard  USA              Half-pipe
#
#      Event gender   Medal
# ...

# %%
mydata=pd.read_csv("http://winterolympicsmedals.com/medals.csv",nrows=5)

# %%
mydata
# Out:
#    Year      City       Sport      Discipline  NOC       Event Event gender  \
# 0  1924  Chamonix     Skating  Figure skating  AUT  individual            M
# 1  1924  Chamonix     Skating  Figure skating  AUT  individual            W
# 2  1924  Chamonix     Skating  Figure skating  AUT       pairs            X
# 3  1924  Chamonix   Bobsleigh       Bobsleigh  BEL    four-man            M
# 4  1924  Chamonix  Ice Hockey      Ice Hockey  CAN  ice hockey            M
#
#     Medal
# 0  Silver
# 1    Gold
# 2    Gold
# 3  Bronze
# 4    Gold

# %%
mydata=pd.read_csv("http://winterolympicsmedals.com/medals.csv",thousands=",")

# %%
mydata
# Out:
#       Year      City       Sport      Discipline  NOC            Event  \
# 0     1924  Chamonix     Skating  Figure skating  AUT       individual
# 1     1924  Chamonix     Skating  Figure skating  AUT       individual
# 2     1924  Chamonix     Skating  Figure skating  AUT            pairs
# 3     1924  Chamonix   Bobsleigh       Bobsleigh  BEL         four-man
# 4     1924  Chamonix  Ice Hockey      Ice Hockey  CAN       ice hockey
# ...    ...       ...         ...             ...  ...              ...
# 2306  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2307  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2308  2006     Turin      Skiing       Snowboard  USA        Half-pipe
# 2309  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
# 2310  2006     Turin      Skiing       Snowboard  USA  Snowboard Cross
#
#      Event gender   Medal
# 0               M  Silver
# 1               W    Gold
# 2               X    Gold
# ...

# %%
mydata=pd.read_csv("http://winterolympicsmedals.com/medals.csv",usecols=[1,5,7])

# %%
mydata
# Out:
#           City            Event   Medal
# 0     Chamonix       individual  Silver
# 1     Chamonix       individual    Gold
# 2     Chamonix            pairs    Gold
# 3     Chamonix         four-man  Bronze
# 4     Chamonix       ice hockey    Gold
# ...        ...              ...     ...
# 2306     Turin        Half-pipe  Silver
# 2307     Turin        Half-pipe    Gold
# 2308     Turin        Half-pipe  Silver
# 2309     Turin  Snowboard Cross    Gold
# 2310     Turin  Snowboard Cross  Silver
#
# [2311 rows x 3 columns]

# %%
mydata=pd.read_csv("http://winterolympicsmedals.com/medals.csv",usecols=[1,5],nrows=4)

# %%
mydata
# Out:
#        City       Event
# 0  Chamonix  individual
# 1  Chamonix  individual
# 2  Chamonix       pairs
# 3  Chamonix    four-man

# %%
mydata=pd.read_csv('data/iris.csv',sep=';')

# %%
mydata
# Out:
#     sepal_length,sepal_width,petal_length,petal_width,species
# 0                                   5.1,3.5,1.4,0.2,se
# 1                                 4.9,3,1.4,0.2,setosa
# 2                               4.7,3.2,1.3,0.2,setosa
# 3                               4.6,3.1,1.5,0.2,setosa
# 4                                 5,3.6,1.4,0.2,setosa
# ..                                                 ...
# 145                            6.7,3,5.2,2.3,virginica
# 146                            6.3,2.5,5,1.9,virginica
# 147                              6.5,3,5.2,2,virginica
# 148                          6.2,3.4,5.4,2.3,virginica
# 149                            5.9,3,5.1,1.8,virginica
#
# [150 rows x 1 columns]

# %%
mydata=pd.read_csv("http://winterolympicsmedals.com/medals.csv",sep=';')

# %%
mydata
# Out:
#      Year,City,Sport,Discipline,NOC,Event,Event gender,Medal
# 0     1924,Chamonix,Skating,Figure skating,AUT,indiv...
# 1     1924,Chamonix,Skating,Figure skating,AUT,indiv...
# 2     1924,Chamonix,Skating,Figure skating,AUT,pairs...
# 3     1924,Chamonix,Bobsleigh,Bobsleigh,BEL,four-man...
# 4     1924,Chamonix,Ice Hockey,Ice Hockey,CAN,ice ho...
# ...                                                 ...
# 2306  2006,Turin,Skiing,Snowboard,USA,Half-pipe,M,Si...
# 2307   2006,Turin,Skiing,Snowboard,USA,Half-pipe,W,Gold
# 2308  2006,Turin,Skiing,Snowboard,USA,Half-pipe,W,Si...
# 2309  2006,Turin,Skiing,Snowboard,USA,Snowboard Cros...
# 2310  2006,Turin,Skiing,Snowboard,USA,Snowboard Cros...
#
# [2311 rows x 1 columns]

# %%
mydata=pd.read_csv('data/iris.csv',dtype={'sepal_length':'float64'})

# %%
mydata.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
mydf=pd.read_csv('data/iris.csv',verbose='True')
# Out:
# Tokenization took: 0.08 ms
# Type conversion took: 0.60 ms
# Parser memory cleanup took: 0.01 ms

# %%
mydf
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2         se
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import csv
with open("data/iris.csv") as f:
  d = csv.DictReader(f)
  l=list(d)

# %%
l
# Out:
# [OrderedDict([('sepal_length', '5.1'),
#               ('sepal_width', '3.5'),
#               ('petal_length', '1.4'),
#               ('petal_width', '0.2'),
#               ('species', 'se')]),
#  OrderedDict([('sepal_length', '4.9'),
#               ('sepal_width', '3'),
#               ('petal_length', '1.4'),
#               ('petal_width', '0.2'),
#               ('species', 'setosa')]),
#  OrderedDict([('sepal_length', '4.7'),
#               ('sepal_width', '3.2'),
#               ('petal_length', '1.3'),
#               ('petal_width', '0.2'),
#               ('species', 'setosa')]),
#  OrderedDict([('sepal_length', '4.6'),
#               ('sepal_width', '3.1'),
#               ('petal_length', '1.5'),
#               ('petal_width', '0.2'),
#               ('species', 'setosa')]),
#  OrderedDict([('sepal_length', '5'),
#               ('sepal_width', '3.6'),
#               ('petal_length', '1.4'),
#               ('petal_width', '0.2'),
# ...
